# %%
import os

print(os.getcwd())
# Out:
# c:\Users\Asus\Desktop\churn_prediction\notebooks

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

sys.path.insert(0, str(PROJECT_ROOT))

print(PROJECT_ROOT)
# Out:
# c:\Users\Asus\Desktop\churn_prediction

# %%
import os

os.chdir(r"C:\Users\Asus\Desktop\churn_prediction")

print(os.getcwd())
# Out:
# C:\Users\Asus\Desktop\churn_prediction

# %%
import os

print("Current Directory:", os.getcwd())
print("Model Exists:", os.path.exists("artifacts/model.pkl"))
print("Absolute Path:", os.path.abspath("artifacts/model.pkl"))
# Out:
# Current Directory: C:\Users\Asus\Desktop\churn_prediction
# Model Exists: True
# Absolute Path: C:\Users\Asus\Desktop\churn_prediction\artifacts\model.pkl

# %%
from pathlib import Path

for file in Path(".").rglob("*.pkl"):
    print(file)
# Out:
# artifacts\model.pkl
# artifacts\preprocessor.pkl

# %%
from src.pipeline.prediction_pipeline import (
    PredictPipeline,
    CustomData
)

# %%
customer = CustomData(
    gender="Male",
    senior_citizen="No",
    partner="Yes",
    dependents="No",
    tenure_months=5,
    phone_service="Yes",
    multiple_lines="No",
    internet_service="Fiber optic",
    online_security="No",
    online_backup="No",
    device_protection="No",
    tech_support="No",
    streaming_tv="Yes",
    streaming_movies="Yes",
    contract="Month-to-month",
    paperless_billing="Yes",
    payment_method="Electronic check",
    monthly_charges=95,
    total_charges=500,
    cltv=5000
)

df = customer.get_data_as_dataframe()

print(df.columns.tolist())
print(df)
# Out:
# ['Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Tenure Months', 'Phone Service', 'Multiple Lines', 'Internet Service', 'Online Security', 'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method', 'Monthly Charges', 'Total Charges', 'CLTV']
#   Gender Senior Citizen Partner Dependents  Tenure Months Phone Service  \
# 0   Male             No     Yes         No              5           Yes
#
#   Multiple Lines Internet Service Online Security Online Backup  \
# 0             No      Fiber optic              No            No
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No          Yes              Yes
#
#          Contract Paperless Billing    Payment Method  Monthly Charges  \
# 0  Month-to-month               Yes  Electronic check               95
#
#    Total Charges  CLTV
# 0            500  5000

# %%
from src.pipeline.prediction_pipeline import (
    PredictPipeline,
    CustomData
)

customer = CustomData(
    gender="Male",
    senior_citizen="No",
    partner="Yes",
    dependents="No",
    tenure_months=5,
    phone_service="Yes",
    multiple_lines="No",
    internet_service="Fiber optic",
    online_security="No",
    online_backup="No",
    device_protection="No",
    tech_support="No",
    streaming_tv="Yes",
    streaming_movies="Yes",
    contract="Month-to-month",
    paperless_billing="Yes",
    payment_method="Electronic check",
    monthly_charges=95,
    total_charges=500,
    cltv=5000
)


df = customer.get_data_as_dataframe()

pipeline = PredictPipeline()

prediction, probability = pipeline.predict(df)

print(prediction)

print(probability)
# Out:
# [1]
# [0.91065987]
# c:\Users\Asus\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\Asus\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
contract="Month-to-month"
internet_service="Fiber optic"
tenure_months=2
monthly_charges=95
